# %%
import math
import itertools
from itertools import product
from itertools import permutations
from math import factorial

# %% [markdown]
# # 1. Задание (теорема сложения)
# Найти вероятность выпадения 2 или 5 очков при подбрасывании игральной кости, на гранях которой имеются соответственно 1,2,3,4,5 и 6 очков.

# %%
# Вероятность выпадения 2 очков, т.к. число возможных событий 6, а число одно:
p2 = 1/6
# Вероятность выпадения 5 очков, т.к. число возможных событий 6, а число одно:
p5 = 1/6
# События независимые, поэтому применяем теорему сложения вероятностей:
p25 = p2 + p5
p25
# Out:
# 0.3333333333333333

# %% [markdown]
# # 2. Задание (теорема умножения)
# Найти вероятность того, что при двух подбрасываниях той же самой игральной кости сначала выпадет 2, а затем 5.

# %%
p2 = 1/6
p5 = 1/6
# События А и В независимые, поэтому применяем теорему умножения вероятностей для не зависимых событий:
p25 = p2*p5
p25
# Out:
# 0.027777777777777776

# %% [markdown]
# # 3. Задание
# Найти вероятность выпадения 2 и 5 очков при двух подбрасываниях той же самой игральной игральной кости. Обратите внимание на порядок выпадения костей!

# %%
p22 = 1/6*1/6
p55 = 1/6*1/6
p2 = (1/6+1/6)-p22
p5 = (1/6+1/6)-p55
p25 = p2*p5
p25
# Out:
# 0.09336419753086418

# %% [markdown]
# # 4. Задание  (Геометрическая вероятность +интервалы)
# На отрезке AB длиной 20 см наугад отметили точку C. Какова вероятность, что она находится на расстоянии не более 9 см от точки А и не более 15 см от точки В?

# %%
AB = 20; AM = 9; NB = 15
MN = AM + NB - AB
p = MN / AB
print('AC <= 9cm, BC <= 15cm с вероятностью',p)
# Out:
# AC <= 9cm, BC <= 15cm с вероятностью 0.2

# %% [markdown]
# # 5. Задание.
#
# Телефонный номер состоит из 7 цифр. Какова вероятность, что это номер 8882227?

# %%
n = 10; k = 7
print('Вероятность, что это номер 8882227:', 1 / n**k)
# Out:
# Вероятность, что это номер 8882227: 1e-07

# %% [markdown]
# # 6. Задание.
#
# Набирая номер телефона, абонент забыл 2 последние цифры, и, помня только то, что эти цифры различны и среди них нет нуля, стал набирать их наудачу. Сколько вариантов ему надо перебрать, чтобы наверняка найти нужный номер? Какова вероятность того, что он угадает номер с первого раза?

# %%
#Поскольку все цифры известны, кроме последних, а также мы знаем, что это не нули, то количество комбинаций будет равно 
#9^2 = 81, отнимем 9 комбинаций, в которых цифры одинаковы (11, 22, 33 и тд), получим 72 цифры нужно перепробовать, 
#а вероятность, что он наберет ее с первого раза 1/72.

# %%
count = factorial(9)/factorial(7)
print('\ncount = ', count)
for p in permutations('123456789',2):
    print(''.join(p), end=' ' )
print(f'\nВероятность угадать номер с первого раза:', 1 / count)
# Out:
# count =  72.0
# 12 13 14 15 16 17 18 19 21 23 24 25 26 27 28 29 31 32 34 35 36 37 38 39 41 42 43 45 46 47 48 49 51 52 53 54 56 57 58 59 61 62 63 64 65 67 68 69 71 72 73 74 75 76 78 79 81 82 83 84 85 86 87 89 91 92 93 94 95 96 97 98
# Вероятность угадать номер с первого раза: 0.013888888888888888

# %% [markdown]
# # 7. Задание** (необязательное)
# Чёрный куб покрасили снаружи белой краской, затем разрезали на 27 одинаковых маленьких кубиков и как попало сложили из них большой куб. С какой вероятностью  все грани этого куба будут белыми?

# %%
# Пусть грань малого куба = 1, 
# площадь стороны = 1, 
# площадь всех сторон 1го малого куба = 6
# площадь всех сторон 27 малых кубов = 6*27 = 162
# Грань большого куба = 3, площадь стороны = 9, всех сторон = 54
# Вероятность того, что 1 грань малого куба белая = 54/162
# Вероятность того, что все 54 наружных грани малых кубов белые = (54/162)**54

((3*3*6)/(1*6*27))**54
# Out:
# 1.7196982334549805e-26
